# %%
import pandas as pd
df = pd.read_csv(r"D:\GITHUB\kotak-school-dbms\output_data\students_data.csv")
df
# Out:
#       s_no adm_no                          name   class  gender  \
# 0        1  17159             CHAITHRA PRESINGU  Pre KG  FEMALE
# 1        2  17349             NANDOLI DAKSHINYA  PRE KG  FEMALE
# 2        3  16935  DHRUVITA PRAARTHANA SAVARAPU  Pre KG  FEMALE
# 3        4  17216                   SANVI KUNDU  PRE KG  FEMALE
# 4        5  17158     DHRUVITHA ALPHONSEY SONGA  Pre KG  FEMALE
# ...    ...    ...                           ...     ...     ...
# 3377  3378  14432     VADAMODULA HARSHA VARDHAN   X - C    MALE
# 3378  3379  13863                UPENDRA MUTCHI   X - C    MALE
# 3379  3380  14236  YADLA VENKATA SIVA NARASIMHA   X - C    MALE
# 3380  3381  14360                VARUN PRESINGI   X - C    MALE
# 3381  3382  13796                  VINAY PIDUGU   X - C    MALE
#
#                     mother_name                          father_name  \
# 0                           NaN                          P VENKATESH
# ...

# %%
df[df["dob"].isna()]
# Out:
# Empty DataFrame
# Columns: [s_no, adm_no, name, class, gender, mother_name, father_name, pen_number, dob, phone_no, religion, caste, sub_caste, second_lang, remarks, class_nos, joined_year, grades, academic_year, status]
# Index: []
